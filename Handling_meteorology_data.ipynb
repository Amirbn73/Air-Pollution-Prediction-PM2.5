# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirbn73/Air-pollution-Prediction/blob/main/Handling_meteorology_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# %%
file = files.upload()
# Out:
#      <input type="file" id="files-f35d09cc-75df-4361-9b8f-9d7772143224" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f35d09cc-75df-4361-9b8f-9d7772143224">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Meteorology data.csv')

# %%
data.head(10)
# Out:
#          Station                      HEATHROW   \
# 0       Latitude                       51.47872
# 1       Longtude                       -0.44904
# 2       Eastings                         507693
# 3      Northings                         176724
# 4   Altitude (m)                             25
# 5         Start:               0000 01/01/2019
# 6           End:               2300 31/12/2021
# 7  Date and time  Daily Maximum Air Temperature
# 8       01-01-20                            8.1
# 9       02-01-20                             11
#
#                       Unnamed: 2            Unnamed: 3             Unnamed: 4  \
# 0                            NaN                   NaN                    NaN
# 1                            NaN                   NaN                    NaN
# 2                            NaN                   NaN                    NaN
# 3                            NaN                   NaN                    NaN
# ...

# %%
data.isnull().sum()
# Out:
# Station                0
#        HEATHROW        0
# Unnamed: 2             7
# Unnamed: 3             7
# Unnamed: 4             7
# Unnamed: 5             7
#        KEW GARDENS     0
# Unnamed: 7             7
# Unnamed: 8             7
# Unnamed: 9             7
# Unnamed: 10            7
#        NORTHOLT        0
# Unnamed: 12            7
# Unnamed: 13            7
# Unnamed: 14            7
# Unnamed: 15            7
#        WISLEY          0
# Unnamed: 17            7
# Unnamed: 18            7
# Unnamed: 19            7
# Unnamed: 20            7
# dtype: int64

# %%
data.tail()
# Out:
#       Station        HEATHROW  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 734  27-12-21             11.2        5.8          5          6         17
# 735  28-12-21             11.8        8.2        1.2         11         36
# 736  29-12-21             15.3        7.1        0.8         10         38
# 737  30-12-21               15        9.8        2.6         14         27
# 738  31-12-21             15.3       12.4          0         11         26
#
#            KEW GARDENS  Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 734                11.2        5.7        4.4          4  ...
# 735                11.8          8        0.8          7  ...
# 736                15.5        6.4        0.8          5  ...
# 737                14.9        9.8        1.8          7  ...
# 738                15.3       12.4        0.2          6  ...
#
#            NORTHOLT  Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# ...

# %%
ds = data.dropna()

# %%
ds.head()
# Out:
#           Station                      HEATHROW   \
# 7   Date and time  Daily Maximum Air Temperature
# 8        01-01-20                            8.1
# 9        02-01-20                             11
# 10       03-01-20                             10
# 11       04-01-20                              9
#
#                        Unnamed: 2            Unnamed: 3  \
# 7   Daily Minimum Air Temperature  Daily Rainfall Total
# 8                             1.7                     0
# 9                             4.7                     2
# 10                              8                     0
# 11                            2.2                     0
#
#                Unnamed: 4                 Unnamed: 5  \
# 7   Daily Mean Wind Speed  Daily Maximum Gust Speed
# 8                       4                         11
# 9                      10                         26
# 10                      9                         24
# 11                      8                         19
#
# ...

# %%
ds.shape
# Out:
# (732, 21)

# %%
ds.head()
# Out:
#           Station                      HEATHROW   \
# 7   Date and time  Daily Maximum Air Temperature
# 8        01-01-20                            8.1
# 9        02-01-20                             11
# 10       03-01-20                             10
# 11       04-01-20                              9
#
#                        Unnamed: 2            Unnamed: 3  \
# 7   Daily Minimum Air Temperature  Daily Rainfall Total
# 8                             1.7                     0
# 9                             4.7                     2
# 10                              8                     0
# 11                            2.2                     0
#
#                Unnamed: 4                 Unnamed: 5  \
# 7   Daily Mean Wind Speed  Daily Maximum Gust Speed
# 8                       4                         11
# 9                      10                         26
# 10                      9                         24
# 11                      8                         19
#
# ...

# %%
# df['Unnamed: 2'].str.contains('V ugm-3').any()

# %%
for i in ds.columns:
  if ds[i].str.contains('V ugm-3').any() or ds[i].str.contains('V mgm-3').any():
    ds.drop(columns = i, inplace = True)

ds.head(20)
# Out:
#           Station                      HEATHROW   \
# 7   Date and time  Daily Maximum Air Temperature
# 8        01-01-20                            8.1
# 9        02-01-20                             11
# 10       03-01-20                             10
# 11       04-01-20                              9
# 12       05-01-20                              9
# 13       06-01-20                            8.9
# 14       07-01-20                           13.1
# 15       08-01-20                           12.8
# 16       09-01-20                           13.4
# 17       10-01-20                            9.9
# 18       11-01-20                           11.4
# 19       12-01-20                           11.7
# 20       13-01-20                           11.2
# 21       14-01-20                           13.3
# 22       15-01-20                           10.2
# 23       16-01-20                           12.7
# 24       17-01-20                            9.6
# ...

# %%
ds.reset_index(inplace= True)

# %%
ds.head()
# Out:
#    index        Station                      HEATHROW   \
# 0      7  Date and time  Daily Maximum Air Temperature
# 1      8       01-01-20                            8.1
# 2      9       02-01-20                             11
# 3     10       03-01-20                             10
# 4     11       04-01-20                              9
#
#                       Unnamed: 2            Unnamed: 3             Unnamed: 4  \
# 0  Daily Minimum Air Temperature  Daily Rainfall Total  Daily Mean Wind Speed
# 1                            1.7                     0                      4
# 2                            4.7                     2                     10
# 3                              8                     0                      9
# 4                            2.2                     0                      8
#
#                   Unnamed: 5                   KEW GARDENS   \
# 0  Daily Maximum Gust Speed   Daily Maximum Air Temperature
# ...

# %%
ds.drop(columns='index', inplace = True)

# %%
ds.head()
# Out:
#          Station                      HEATHROW   \
# 0  Date and time  Daily Maximum Air Temperature
# 1       01-01-20                            8.1
# 2       02-01-20                             11
# 3       03-01-20                             10
# 4       04-01-20                              9
#
#                       Unnamed: 2            Unnamed: 3             Unnamed: 4  \
# 0  Daily Minimum Air Temperature  Daily Rainfall Total  Daily Mean Wind Speed
# 1                            1.7                     0                      4
# 2                            4.7                     2                     10
# 3                              8                     0                      9
# 4                            2.2                     0                      8
#
#                   Unnamed: 5                   KEW GARDENS   \
# 0  Daily Maximum Gust Speed   Daily Maximum Air Temperature
# 1                         11                            7.9
# ...

# %%
# Assuming df is your initial DataFrame

# Create a new DataFrame with the desired column structure
new_columns = []

# First, add the 'Date' column as is
new_columns.append(('Date', ''))

# Iterate through the columns representing stations and pollutants
station_names = []
pollutant_names = []

for i, column_name in enumerate(ds.columns[1:]):
    if i % 5 == 0:
        station_name = column_name
        station_names.extend([station_name] * 5)
    pollutant_names.extend(list(ds.drop(columns='Station').loc[0]))
    # pollutant_names.extend([pollutant_name] * 4)

new_columns.extend(list(zip(station_names, pollutant_names)))

# # Create the new DataFrame with the modified column structure
# new_df = ds.copy()
ds.columns = pd.MultiIndex.from_tuples(new_columns, names=['Station', 'Parameter'])

# # Now, you have a new DataFrame with the desired multi-index structure

# %%
new_columns
# Out:
# [('Date', ''),
#  ('       HEATHROW ', 'Daily Maximum Air Temperature'),
#  ('       HEATHROW ', 'Daily Minimum Air Temperature'),
#  ('       HEATHROW ', 'Daily Rainfall Total'),
#  ('       HEATHROW ', 'Daily Mean Wind Speed'),
#  ('       HEATHROW ', 'Daily Maximum Gust Speed '),
#  ('       KEW GARDENS ', 'Daily Maximum Air Temperature'),
#  ('       KEW GARDENS ', 'Daily Minimum Air Temperature'),
#  ('       KEW GARDENS ', 'Daily Rainfall Total'),
#  ('       KEW GARDENS ', 'Daily Mean Wind Speed'),
#  ('       KEW GARDENS ', 'Daily Maximum Gust Speed '),
#  ('       NORTHOLT ', 'Daily Maximum Air Temperature'),
#  ('       NORTHOLT ', 'Daily Minimum Air Temperature'),
#  ('       NORTHOLT ', 'Daily Rainfall Total'),
#  ('       NORTHOLT ', 'Daily Mean Wind Speed'),
#  ('       NORTHOLT ', 'Daily Maximum Gust Speed '),
#  ('       WISLEY ', 'Daily Maximum Air Temperature'),
#  ('       WISLEY ', 'Daily Minimum Air Temperature'),
#  ('       WISLEY ', 'Daily Rainfall Total'),
# ...

# %%
ds.head()
# Out:
# Station             Date                      HEATHROW   \
# Parameter                 Daily Maximum Air Temperature
# 0          Date and time  Daily Maximum Air Temperature
# 1               01-01-20                            8.1
# 2               02-01-20                             11
# 3               03-01-20                             10
# 4               04-01-20                              9
#
# Station                                                         \
# Parameter  Daily Minimum Air Temperature  Daily Rainfall Total
# 0          Daily Minimum Air Temperature  Daily Rainfall Total
# 1                                    1.7                     0
# 2                                    4.7                     2
# 3                                      8                     0
# 4                                    2.2                     0
#
# Station                                                      \
# Parameter  Daily Mean Wind Speed  Daily Maximum Gust Speed
# ...

# %%
ds.drop(0, inplace = True)

# %%
ds.head(3)
# Out:
# Station        Date                     HEATHROW   \
# Parameter           Daily Maximum Air Temperature
# 1          01-01-20                           8.1
# 2          02-01-20                            11
# 3          03-01-20                            10
#
# Station                                                       \
# Parameter Daily Minimum Air Temperature Daily Rainfall Total
# 1                                   1.7                    0
# 2                                   4.7                    2
# 3                                     8                    0
#
# Station                                                    \
# Parameter Daily Mean Wind Speed Daily Maximum Gust Speed
# 1                             4                        11
# 2                            10                        26
# 3                             9                        24
#
# Station                    KEW GARDENS                                 \
# ...

# %%
ds.shape
# Out:
# (731, 21)

# %%
# Convert the "Date_Column" to the datetime data type
ds['Date'] = pd.to_datetime(ds['Date'], format='%d-%m-%y')

# After running this, the "Date_Column" will be converted to the datetime data type.

# %%
# Format the date as 'Mon YYYY' and create a new column with the long date format
# ds['Date'] = ds['Date'].dt.strftime('%b %Y')

# %%
ds.head(3)
# Out:
# Station         Date                     HEATHROW   \
# Parameter            Daily Maximum Air Temperature
# 1         2020-01-01                           8.1
# 2         2020-01-02                            11
# 3         2020-01-03                            10
#
# Station                                                       \
# Parameter Daily Minimum Air Temperature Daily Rainfall Total
# 1                                   1.7                    0
# 2                                   4.7                    2
# 3                                     8                    0
#
# Station                                                    \
# Parameter Daily Mean Wind Speed Daily Maximum Gust Speed
# 1                             4                        11
# 2                            10                        26
# 3                             9                        24
#
# Station                    KEW GARDENS                                 \
# ...

# %%
# Assuming you already have a DataFrame called df
ds.set_index("Date", inplace=True)

# %%
ds.tail(2)
# Out:
# Station                        HEATHROW                                 \
# Parameter  Daily Maximum Air Temperature Daily Minimum Air Temperature
# Date
# 2021-12-30                            15                           9.8
# 2021-12-31                          15.3                          12.4
#
# Station                                                \
# Parameter  Daily Rainfall Total Daily Mean Wind Speed
# Date
# 2021-12-30                  2.6                    14
# 2021-12-31                    0                    11
#
# Station                                               KEW GARDENS   \
# Parameter  Daily Maximum Gust Speed  Daily Maximum Air Temperature
# Date
# 2021-12-30                        27                          14.9
# 2021-12-31                        26                          15.3
#
# Station                                                        \
# Parameter  Daily Minimum Air Temperature Daily Rainfall Total
# Date
# ...

# %%
import numpy as np

# %%
ds = ds.replace('No data', np.nan)

# %%
ds.fillna(method='ffill',inplace = True)

# %%
# Count occurrences of 'No data' in each column
ds.isnull().sum()
# Out:
# Station              Parameter
#        HEATHROW      Daily Maximum Air Temperature    0
#                      Daily Minimum Air Temperature    0
#                      Daily Rainfall Total             0
#                      Daily Mean Wind Speed            0
#                      Daily Maximum Gust Speed         0
#        KEW GARDENS   Daily Maximum Air Temperature    0
#                      Daily Minimum Air Temperature    0
#                      Daily Rainfall Total             0
#                      Daily Mean Wind Speed            0
#                      Daily Maximum Gust Speed         0
#        NORTHOLT      Daily Maximum Air Temperature    0
#                      Daily Minimum Air Temperature    0
#                      Daily Rainfall Total             0
#                      Daily Mean Wind Speed            0
#                      Daily Maximum Gust Speed         0
#        WISLEY        Daily Maximum Air Temperature    0
# ...

# %%
ds.tail(2)
# Out:
# Station                        HEATHROW                                 \
# Parameter  Daily Maximum Air Temperature Daily Minimum Air Temperature
# Date
# 2021-12-30                            15                           9.8
# 2021-12-31                          15.3                          12.4
#
# Station                                                \
# Parameter  Daily Rainfall Total Daily Mean Wind Speed
# Date
# 2021-12-30                  2.6                    14
# 2021-12-31                    0                    11
#
# Station                                               KEW GARDENS   \
# Parameter  Daily Maximum Gust Speed  Daily Maximum Air Temperature
# Date
# 2021-12-30                        27                          14.9
# 2021-12-31                        26                          15.3
#
# Station                                                        \
# Parameter  Daily Minimum Air Temperature Daily Rainfall Total
# Date
# ...

# %%
ds = ds.astype(float)

# %%
ds['month'] = ds.index.strftime('%b %Y')

# %%
ds.tail(2)
# Out:
# Station                        HEATHROW                                 \
# Parameter  Daily Maximum Air Temperature Daily Minimum Air Temperature
# Date
# 2021-12-30                          15.0                           9.8
# 2021-12-31                          15.3                          12.4
#
# Station                                                \
# Parameter  Daily Rainfall Total Daily Mean Wind Speed
# Date
# 2021-12-30                  2.6                  14.0
# 2021-12-31                  0.0                  11.0
#
# Station                                               KEW GARDENS   \
# Parameter  Daily Maximum Gust Speed  Daily Maximum Air Temperature
# Date
# 2021-12-30                      27.0                          14.9
# 2021-12-31                      26.0                          15.3
#
# Station                                                        \
# Parameter  Daily Minimum Air Temperature Daily Rainfall Total
# Date
# ...

# %%
# Group the DataFrame by the 'month' column and calculate the mean for each group
final = ds.groupby(by=["month"]).mean()

# %%
# Convert the index to datetime format
final.index = pd.to_datetime(final.index, format='%b %Y')

# Sort the DataFrame based on the datetime index
k = final.sort_index()

# %%
k
# Out:
# Station                        HEATHROW                                 \
# Parameter  Daily Maximum Air Temperature Daily Minimum Air Temperature
# month
# 2020-01-01                     10.090323                      4.693548
# 2020-02-01                     11.082759                      4.327586
# 2020-03-01                     12.038710                      3.848387
# 2020-04-01                     18.220000                      6.456667
# 2020-05-01                     21.106452                      9.135484
# 2020-06-01                     22.526667                     12.590000
# 2020-07-01                     23.783871                     13.396774
# 2020-08-01                     25.548387                     15.583871
# 2020-09-01                     21.626667                     11.250000
# 2020-10-01                     15.077419                      8.758065
# 2020-11-01                     12.740000                      6.156667
# ...

# %%
k.index = k.index.strftime('%b %Y')

# %%
k
# Out:
# Station                       HEATHROW                                 \
# Parameter Daily Maximum Air Temperature Daily Minimum Air Temperature
# month
# Jan 2020                      10.090323                      4.693548
# Feb 2020                      11.082759                      4.327586
# Mar 2020                      12.038710                      3.848387
# Apr 2020                      18.220000                      6.456667
# May 2020                      21.106452                      9.135484
# Jun 2020                      22.526667                     12.590000
# Jul 2020                      23.783871                     13.396774
# Aug 2020                      25.548387                     15.583871
# Sep 2020                      21.626667                     11.250000
# Oct 2020                      15.077419                      8.758065
# Nov 2020                      12.740000                      6.156667
# ...

# %%
# Assuming your DataFrame is named 'df' and you want to save it to 'output.csv'
# k.T.to_csv('output.csv')  # Use index=False to exclude row indices in the output

# %%
final = k.T

# %%
final
# Out:
# month                                               Jan 2020   Feb 2020  \
# Station             Parameter
#        HEATHROW     Daily Maximum Air Temperature  10.090323  11.082759
#                     Daily Minimum Air Temperature   4.693548   4.327586
#                     Daily Rainfall Total            1.535484   3.441379
#                     Daily Mean Wind Speed           8.967742  14.103448
#                     Daily Maximum Gust Speed       22.709677  33.482759
#        KEW GARDENS  Daily Maximum Air Temperature  10.119355  11.051724
#                     Daily Minimum Air Temperature   3.732258   3.941379
#                     Daily Rainfall Total            1.767742   3.379310
#                     Daily Mean Wind Speed           4.806452   7.344828
#                     Daily Maximum Gust Speed       19.064516  28.655172
#        NORTHOLT     Daily Maximum Air Temperature   9.980645  10.731034
#                     Daily Minimum Air Temperature   4.148387   3.817241
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
final.index
# Out:
# MultiIndex([(   '       HEATHROW ', 'Daily Maximum Air Temperature'),
#             (   '       HEATHROW ', 'Daily Minimum Air Temperature'),
#             (   '       HEATHROW ',          'Daily Rainfall Total'),
#             (   '       HEATHROW ',         'Daily Mean Wind Speed'),
#             (   '       HEATHROW ',     'Daily Maximum Gust Speed '),
#             ('       KEW GARDENS ', 'Daily Maximum Air Temperature'),
#             ('       KEW GARDENS ', 'Daily Minimum Air Temperature'),
#             ('       KEW GARDENS ',          'Daily Rainfall Total'),
#             ('       KEW GARDENS ',         'Daily Mean Wind Speed'),
#             ('       KEW GARDENS ',     'Daily Maximum Gust Speed '),
#             (   '       NORTHOLT ', 'Daily Maximum Air Temperature'),
#             (   '       NORTHOLT ', 'Daily Minimum Air Temperature'),
#             (   '       NORTHOLT ',          'Daily Rainfall Total'),
# ...

# %%
final.index.levels[0][0:4]
# Out:
# Index(['       HEATHROW ', '       KEW GARDENS ', '       NORTHOLT ',
#        '       WISLEY '],
#       dtype='object', name='Station')

# %%
import pandas as pd

# Assuming 'M' is your original DataFrame
# Create an empty DataFrame 'X' with station names as row indices
X = pd.DataFrame(index=final.index.levels[0][0:4])

# # Iterate through rows in 'M' and populate 'X'
for month in final.columns:
  for station, pollutant in final.index:
    column_name = f"{month}-{pollutant}"
    X.loc[station, column_name] = final.loc[(station, pollutant), month]
X
# Out:
#                      Jan 2020-Daily Maximum Air Temperature  \
# Station
#        HEATHROW                                   10.090323
#        KEW GARDENS                                10.119355
#        NORTHOLT                                    9.980645
#        WISLEY                                      9.770968
#
#                      Jan 2020-Daily Minimum Air Temperature  \
# Station
#        HEATHROW                                    4.693548
#        KEW GARDENS                                 3.732258
#        NORTHOLT                                    4.148387
#        WISLEY                                      4.287097
#
#                      Jan 2020-Daily Rainfall Total  \
# Station
#        HEATHROW                           1.535484
#        KEW GARDENS                        1.767742
#        NORTHOLT                           1.664516
#        WISLEY                             1.864516
#
#                      Jan 2020-Daily Mean Wind Speed  \
# Station
# ...

# %%
Average_data = X.copy()

# %%
# List of column names containing 'Carbon monoxide'
columns_to_multiply = [col for col in Average_data.columns if 'Carbon monoxide' in col]

# Multiply the selected columns by 1000
Average_data[columns_to_multiply] = Average_data[columns_to_multiply] * 1000

# %%
Average_data
# Out:
#                      Jan 2020-Daily Maximum Air Temperature  \
# Station
#        HEATHROW                                   10.090323
#        KEW GARDENS                                10.119355
#        NORTHOLT                                    9.980645
#        WISLEY                                      9.770968
#
#                      Jan 2020-Daily Minimum Air Temperature  \
# Station
#        HEATHROW                                    4.693548
#        KEW GARDENS                                 3.732258
#        NORTHOLT                                    4.148387
#        WISLEY                                      4.287097
#
#                      Jan 2020-Daily Rainfall Total  \
# Station
#        HEATHROW                           1.535484
#        KEW GARDENS                        1.767742
#        NORTHOLT                           1.664516
#        WISLEY                             1.864516
#
#                      Jan 2020-Daily Mean Wind Speed  \
# Station
# ...

# %%
# Average_data.to_csv('Last_Final.csv')
Average_data
# Out:
#                      Jan 2020-Daily Maximum Air Temperature  \
# Station
#        HEATHROW                                   10.090323
#        KEW GARDENS                                10.119355
#        NORTHOLT                                    9.980645
#        WISLEY                                      9.770968
#
#                      Jan 2020-Daily Minimum Air Temperature  \
# Station
#        HEATHROW                                    4.693548
#        KEW GARDENS                                 3.732258
#        NORTHOLT                                    4.148387
#        WISLEY                                      4.287097
#
#                      Jan 2020-Daily Rainfall Total  \
# Station
#        HEATHROW                           1.535484
#        KEW GARDENS                        1.767742
#        NORTHOLT                           1.664516
#        WISLEY                             1.864516
#
#                      Jan 2020-Daily Mean Wind Speed  \
# Station
# ...

# %%
Average_data.to_csv('Meteorolgy_fixed.csv')
